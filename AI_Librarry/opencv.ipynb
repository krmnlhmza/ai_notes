# %%
import cv2
import cv2 as cv
import numpy as np
img = cv.imread(r"C:\Users\user\Desktop\kimlik.jpg")

cv.imshow("KIMLIK", img)
roi = img[0:100,0:90]
cv.imshow("ROI", roi)
cv.imwrite("ROI.jpg", roi)#kaydetti



rgb2= cv.merge((r, g, b))
cv.imshow("RGB2", rgb2)
cv.waitKey(0)

# %%
import cv2
import cv2 as cv
import numpy as np
img_rgb = cv.imread(r"C:\Users\user\Downloads\rgb22.jpg")
b, g, r= cv.split(img_rgb)

cv.imshow("B", b)
cv.imshow("G", g)
cv.imshow("R", r)

rgb2= cv.merge((r, g, b))

cv.imshow("RGB2", rgb2)
cv.waitKey(0)
